# %% [markdown]
# <h1>CHAPTER 3 // BASIC DATA STRUCTURES</h1>

# %% [markdown]
# <h1>Objectives</h1>
# <h3><li>Stack</li>
#     <li>Queue</li>
#     <li>Deque</li>
#     <li>List</li>
#     </h3>
# 개념, 규칙, 차이점의 이해 및 활용을 목표로!

# %% [markdown]
# <h3>Linear DATA STRUCTURES</h3><br>
# Stack = LIFO (Last In First Out)<br>
# Queue = FIFO (First In First Out)<br>
# Deque = FIFO + LIFO<br>
# List = Deque + middle intervention

# %% [markdown]
# <h2> Stack </h2>

# %% [markdown]
# - 가장 나중에 들어간 데이타가 제일 먼저 나오게된다.<br>
# - 일반적으로 리스트가 스택을 구현한다. <br>
# (append 가 PUSH 의 개념으로 뒤에 붙고, pop 을 할 경우 가장 나중에 붙은것이 나온다)

# %%
from IPython.display import Image
url ='https://upload.wikimedia.org/wikipedia/commons/b/b4/Lifo_stack.png'

Image(url)

# %% [markdown]
# 여기서 stack 의 중요한 포인트는 reverse 가 가능하다는 것!

# %%
stack = [ 1,2,3,4,5,6]

new_stack = []
for i in range(len(stack)):
    new_stack.append(stack.pop())

new_stack
# Out:
# [6, 5, 4, 3, 2, 1]

# %% [markdown]
# 이러한 stack 을 class 로 작성해보자.

# %%
class Stack:
    def __init__(self):
        self.items = []
    
    def pop(self):
        return self.items.pop()
    
    def push(self, item):
        return self.items.append(item)
    
    def is_empty(self):
        return self.items == []
    
    def peek(self):
        return self.items[-1]
    
    def size(self):
        return len(self.items)

# %%
s = Stack()
print (s.is_empty())
s.push(4)
s.push('dog')
print (s.peek())
s.push(True)
print (s.size())
print (s.pop())
print (s.pop())
print (s.size())
# Out:
# True
# dog
# 3
# True
# dog
# 1

# %%
# 스택에서 가장 앞쪽으로 집어넣고 뽑아 넣으려면??

class Stack_insert_front:
    def __init__(self):
        self.items = []
    
    # 변경해주세요
    def pop(self):
        return self.items.pop()
    
    # 여기도 변경해주세요, insert module 사용.
    def push(self, item):
        return self.items.append(item)
    
    def is_empty(self):
        return self.items == []
    
    # 여기도 변경요
    def peek(self):
        return self.items[-1]
    
    def size(self):
        return len(self.items)

# %%
a= Stack_insert_front()
a.push("hello")
a.push("second")
a.push("third")
a.peek()
a.pop()
a.pop()
a.peek()
# Out:
# 'third'
# 'third'
# 'second'
# 'hello'

# %% [markdown]
# <h2> Queues </h2>

# %%
from IPython.display import Image
url = 'https://netmatze.files.wordpress.com/2014/08/queue.png'
Image(url)

# %% [markdown]
# Queue 에는 엔큐(<b>Enqueue</b>) 와 데큐(<b>Dequeue</b>) 의 개념이 있는데,<br>
#
# enqueue 의 경우는 끝에 부분에 추가(push)하는 큐의 특징을 설명하고 <br>
#
# dequeue 의 경우는 앞부분에서 pop 을 하는 것을 특징으로 한다.

# %% [markdown]
# <img src="queue.png">

# %%
# Create a Queues Class

class Queue:
    def __init__(self):
        self.items = []
    
    def is_empty(self):
        return self.items == []
    
    def enqueue(self,item):
        return #작성해주세요
    
    def dequeue(self):
        return #작성해주세요
    
    def size(self):
        return len(self.items)

# %%
q = Queue()
q.enqueue('hello')
q.is_empty()
q.enqueue('second')
q.enqueue('third')
q.dequeue()
q.size()
# Out:
# True
# 0

# %% [markdown]
# <h2> Deques </h2>

# %% [markdown]
# 일종의 양방향 queue 라고 볼 수 있다. <br>
#
# 즉, 양방향 rotation 을 구사할 수 있다.

# %%
from IPython.display import Image
Image('http://www.codeproject.com/KB/recipes/669131/deque.png')

# %%
# Create a Deque Class

class Deque:
    def __init__(self):
        self.items = []
    
    def is_empty(self):
        return self.items == []
    
    def addfront(self,item):
        return self.items.insert(0,item)#작성해주세요
    
    def addrear(self,item):
        return self.items.append(item)#작성해주세요
    
    def removefront(self):
        return self.items.pop(0)#작성해주세요
    
    def removerear(self):
        return self.items.pop()#작성해주세요
    
    def size(self):
        return len(self.items)

# %%
d=Deque()
d.addfront("hello")
d.addrear("world")

d.removefront() + " " + d.removerear()
# Out:
# 'hello world'

# %% [markdown]
# <h1> 연습문제 </h1>

# %%
# Balanced Parenthesis 괄호들이 잘 닫혀 있는지 확인하는 함수 작성.

from stack_example import Stack

def par_checker(symbol_string):
    s = Stack()
    balanced = True
    index = 0
    
    # 왼쪽에서 오른쪽으로 하나씩 확인
    while index < len(symbol_string) and balanced:
        symbol = symbol_string[index]
        if symbol == "(":
            s.push(symbol)
        else:
            if s.is_empty():
                balanced = False
            else:
                s.pop()
                
        index = index + 1
        
    if balanced and s.is_empty():
        return True
    else:
        return False

print (par_checker('(((())))'))
print (par_checker('((())'))
# Out:
# True
# False

# %%
# Completed exteded par_checker for : [,{,(,),},]
# Balanced Parenthesis

from stack_example import Stack

def par_checker(symbol_string):
    s = Stack()
    balanced = True
    index = 0
    while index < len(symbol_string) and balanced:
        symbol = symbol_string[index]
        if symbol in "([{":
            s.push(symbol)
        else:
            if s.is_empty():
                balanced = False
            else:
                top = s.pop()
                if not matches (top, symbol):
                    balanced = False
        index = index + 1
    if balanced and s.is_empty():
        return True
    else:
        return False
    
def matches(open,close):
    opens = "([{"
    closes = ")]}"
    return opens.index(open) == closes.index(close)

print (par_checker('{{([][])}()}'))
print (par_checker('[{()]]'))
# Out:
# True
# False

# %% [markdown]
#  <h4> Converting Decimal Numbers to Binary Numbers </h4>

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202017-11-21%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%202.40.35.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202017-11-21%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%202.40.35.png)

# %%
from stack_example import Stack

def divide_by_2(dec_number):
    rem_stack = Stack()
    
    while dec_number > 0:
        rem = dec_number % 2
        rem_stack.push(rem)       # 나머지는 이진수로 입력하고
        dec_number = dec_number // 2  # 몫은 다시 나누기 위해 dec_number로 
        
    bin_string = ""
    while not rem_stack.is_empty():
        bin_string = bin_string + str(rem_stack.pop())  # 거꾸로 뒤집기 위해서
        
    return bin_string
    
print (divide_by_2(233))
# Out:
# 11101001

# %%
# Greater then 2 digits

from stack_example import Stack

def base_converter(dec_number, base):
    digits = "0123456789ABCDEF"
    
    rem_stack = Stack()
    while dec_number > 0:
        rem = dec_number % base
        rem_stack.push(rem)
        dec_number = dec_number // base
    
    new_string = ""
    while not rem_stack.is_empty():
        new_string = new_string + digits[rem_stack.pop()]  #digits 를 index 함으로 16진수로
        
    return new_string

print (base_converter(25, 2))
print (base_converter(233, 16))
# Out:
# 11001
# E9

# %% [markdown]
# <h4>Infix, Prefix, and Postfix Expressions</h4>

# %% [markdown]
# Infix = (A + B) * C <br>
#
# Prefix = *+ABC <br>
#
# Postfix = AB+C* <br>

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202017-11-22%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%204.11.13.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202017-11-22%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%204.11.13.png)

# %%
from stack_example import Stack

def infix_to_postfix(infix_expre):
    prec = {}
    prec["*"] = 3
    prec["/"] = 3
    prec["+"] = 2
    prec["-"] = 2
    prec["("] = 1
    op_stack = Stack()
    postfix_list = []
    token_list = list(infix_expre)
    
    for token in token_list:
        if token in "ABCDEFGHIJKLMNOPQRSTUVWXYZ" or token in  "0123456789":
            postfix_list.append(token)
        elif token == '(':
            op_stack.push(token)
        elif token == ')':
            top_token = op_stack.pop()
            while top_token != '(':
                postfix_list.append(top_token)
                top_token = op_stack.pop()
        else:
            while (not op_stack.is_empty()) and (prec[op_stack.peek()] >= prec[token]):
                postfix_list.append(op_stack.pop())
            op_stack.push(token)
    
    while not op_stack.is_empty():
        postfix_list.append(op_stack.pop())
    
    return " ".join(postfix_list)

print (infix_to_postfix("(A+B)*C-(D-E)*(F-G)"))
print (infix_to_postfix("(A+B)*(C+D)"))
print (infix_to_postfix("(A+B)*C"))
print (infix_to_postfix("A+B*C"))
# Out:
# A B + C * D E - F G - * -
# A B + C D + *
# A B + C *
# A B C * +

# %% [markdown]
# <h3>Example infix_to_postfix("(A+B)*(C+D)")</h3>
#  * for loop of token
#     "("  :  op.stack = ["("]<br>
#     "A"  :  postfix_list = ["A"]<br>
#     "+"  :  op.stack = ["(", "+"]<br>
#     "B"  :  postfix_list = ["A", "B"]<br>
#     ")"  :  top_token = "+" <br>
#             postfix_list = ["A", "B", "+"]<br>
#             top_token = "("<br>
#             op.stack =[]<br>
#     "*"  :  op.stack = ["*"]<br>
#     "("  :  op.stack = ["*", "("]<br>
#     "C"  :  postfix_list = ["A","B", "+", "C"]<br>
#     "+"  :  op.stack = ["*", "(", "+"]<br>
#     "D"  :  postfix_list = ["A","B","+","C","D"]<br>
#     ")"  : top_token = "+"<br>
#            postfix_list = ["A","B","+","C","D","+"]<br>
#            top_token = "("<br>
#            op.stack = ["*"]<br>
#            postfix_list = ["A","B","+","C","D","+","*"]<br>
#     <br>
#     join! ==> AB+CD+*

# %% [markdown]
# <h3>Queue(큐) 의 간단한 사용 예시 게임)</h3><br>
#
# Queue 는 구조상 한쪽 방향으로만 계속 가기 때문에 원형으로 생각할 수 있다. <br>
#
# 그래서 단방향 rotation 구조를 고려할 때 사용하기에 좋다.

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202017-11-22%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2010.23.32.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202017-11-22%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2010.23.32.png)

# %%
#Hot Potato Game

from queues import Queue

def hot_potato(name_list,num):
    sim_queue = Queue()
    for name in name_list:
        sim_queue.enqueue(name)   #우선 이름들을 리스트에 정리해놓기
        
    while sim_queue.size() > 1:      # 1명이 남을때까지
        for i in range (num):
            sim_queue.enqueue(sim_queue.dequeue())  #처음것을 빼서 가장뒤로 붙이기
        sim_queue.dequeue()                      # num 번째를 빼 내고 다시 loop!
        
    return sim_queue.dequeue()  #최후의 생존자

names = ["Bill","David", "Susan", "Jane", "Kent", "Brad"]
hot_potato(names,7)
# Out:
# 'Susan'

# %% [markdown]
# <h3>Palindrome Game</h3> (앞으로 읽으나, 뒤로 읽으나 똑같은 경우 ex) radar, racecar)

# %%
def palindr_checker(a_string):
    char_deque = Deque()
    
    for ch in a_string:
        char_deque.addrear(ch)
    
    still_equal = True
    
    while char_deque.size() > 1 and still_equal:
        first = char_deque.removefront()
        last = char_deque.removerear()
        if first != last:
            still_equal = False
        
    return still_equal

# %%
palindr_checker("basldflaaef")
# Out:
# False

# %%
palindr_checker("radar")
# Out:
# True

# %%
palindr_checker("madam")
# Out:
# True

# %% [markdown]
# <h1> List </h1>

# %% [markdown]
# 순서없이 정렬되어 있을 수 있으며, 중복이 가능하다
